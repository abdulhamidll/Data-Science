# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulhamidll/Data-Science/blob/main/taqsimot_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv",)
df = df[df.year > 2010]
df = df[df.transmission != 'Other']
df = df[df.fuelType != 'Other']
df.head()
# Out:
#        model  year   price transmission  mileage fuelType  tax   mpg  \
# 1    S Class  2017   34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016   49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016   61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016   73948    Automatic     4000   Petrol  325  30.1
# 5   SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
#
#    engineSize
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0
# 5         6.2

# %%
df.shape
# Out:
# (12952, 9)

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=df,  x='price')
plt.show()

# %%
sns.displot(data=df, x='price', hue="transmission", multiple='stack', height=6, aspect=2)
plt.show()

# %%
sns.displot(data=df, x='price', col="transmission", height=6, aspect=2)
plt.show()

# %%
sns.displot(data=df, x='price', kind='kde', height=6, aspect=2)
plt.show()

# %%
sns.displot(data=df, x='price', kde=True, height=6, aspect=2)
plt.show()

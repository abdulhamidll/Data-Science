# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulhamidll/Data-Science/blob/main/import_sqlite3_as_sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3 as sql
from pprint import pprint as print

# %%
# !wget https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Out:
# --2022-05-17 11:16:55--  https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Resolving www.sqlitetutorial.net (www.sqlitetutorial.net)... 151.139.128.11
# Connecting to www.sqlitetutorial.net (www.sqlitetutorial.net)|151.139.128.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 305596 (298K) [application/zip]
# Saving to: ‘chinook.zip’
#
# chinook.zip         100%[===================>] 298.43K  --.-KB/s    in 0.1s
#
# 2022-05-17 11:16:56 (2.81 MB/s) - ‘chinook.zip’ saved [305596/305596]

# %%
# !unzip chinook.zip
# Out:
# Archive:  chinook.zip
# replace chinook.db? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: chinook.db

# %%
db = sql.connect("chinook.db")
cursor = db.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# komanda = "SELECT CustomerId, Firstname, LastName, Phone, Country FROM customers"
# df = pd.read_sql(komanda, db, index_col="CustomerId")
# df
# Out:
# [('albums',),
#  ('sqlite_sequence',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',),
#  ('sqlite_stat1',)]

# %%
query = "SELECT FirstName, LastName, City, State, Phone, Email FROM customers ORDER BY FirstName"
pd.read_sql(query, db)
# Out:
#     FirstName      LastName                 City   State                Phone  \
# 0       Aaron      Mitchell             Winnipeg      MB    +1 (204) 452-6452
# 1   Alexandre         Rocha            São Paulo      SP   +55 (11) 3055-3278
# 2      Astrid        Gruber               Vienne    None       +43 01 5134505
# 3       Bjørn        Hansen                 Oslo    None      +47 22 44 22 22
# 4     Camille       Bernard                Paris    None   +33 01 49 70 65 65
# 5        Daan       Peeters             Brussels    None     +32 02 219 03 03
# 6         Dan        Miller        Mountain View      CA    +1 (650) 644-3358
# 7       Diego     Gutiérrez         Buenos Aires    None  +54 (0)11 4311 4333
# 8   Dominique      Lefebvre                Paris    None   +33 01 47 42 71 71
# 9     Eduardo       Martins            São Paulo      SP   +55 (11) 3033-5446
# 10     Edward       Francis               Ottawa      ON    +1 (613) 234-3322
# ...

# %%
query = "SELECT DISTINCT Country FROM customers"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('Brazil',),
#  ('Germany',),
#  ('Canada',),
#  ('Norway',),
#  ('Czech Republic',),
#  ('Austria',),
#  ('Belgium',),
#  ('Denmark',),
#  ('USA',),
#  ('Portugal',),
#  ('France',),
#  ('Finland',),
#  ('Hungary',),
#  ('Ireland',),
#  ('Italy',),
#  ('Netherlands',),
#  ('Poland',),
#  ('Spain',),
#  ('Sweden',),
#  ('United Kingdom',),
#  ('Australia',),
#  ('Argentina',),
#  ('Chile',),
#  ('India',)]

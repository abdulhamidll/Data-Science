# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulhamidll/Data-Science/blob/main/import_sqlite3_as_sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3 as sql
from pprint import pprint as print

# %%
# !wget https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Out:
# --2022-05-17 11:16:55--  https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Resolving www.sqlitetutorial.net (www.sqlitetutorial.net)... 151.139.128.11
# Connecting to www.sqlitetutorial.net (www.sqlitetutorial.net)|151.139.128.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 305596 (298K) [application/zip]
# Saving to: ‘chinook.zip’
#
# chinook.zip         100%[===================>] 298.43K  --.-KB/s    in 0.1s
#
# 2022-05-17 11:16:56 (2.81 MB/s) - ‘chinook.zip’ saved [305596/305596]

# %%
# !unzip chinook.zip
# Out:
# Archive:  chinook.zip
# replace chinook.db? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: chinook.db

# %%
db = sql.connect("chinook.db")
cursor = db.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# komanda = "SELECT CustomerId, Firstname, LastName, Phone, Country FROM customers"
# df = pd.read_sql(komanda, db, index_col="CustomerId")
# df
# Out:
# [('albums',),
#  ('sqlite_sequence',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',),
#  ('sqlite_stat1',)]

# %%
query = "SELECT FirstName, LastName, City, State, Phone, Email FROM customers"
pd.read_sql(query, db)
# Out:
#     FirstName      LastName                 City   State                Phone  \
# 0        Luís     Gonçalves  São José dos Campos      SP   +55 (12) 3923-5555
# 1      Leonie        Köhler            Stuttgart    None     +49 0711 2842222
# 2    François      Tremblay             Montréal      QC    +1 (514) 721-4711
# 3       Bjørn        Hansen                 Oslo    None      +47 22 44 22 22
# 4   František   Wichterlová               Prague    None     +420 2 4172 5555
# 5      Helena          Holý               Prague    None     +420 2 4177 0449
# 6      Astrid        Gruber               Vienne    None       +43 01 5134505
# 7        Daan       Peeters             Brussels    None     +32 02 219 03 03
# 8        Kara       Nielsen           Copenhagen    None       +453 3331 9991
# 9     Eduardo       Martins            São Paulo      SP   +55 (11) 3033-5446
# 10  Alexandre         Rocha            São Paulo      SP   +55 (11) 3055-3278
# 11    Roberto       Almeida       Rio de Janeiro      RJ   +55 (21) 2271-7000
# 12   Fernanda         Ramos             Brasília      DF   +55 (61) 3363-5547
# 13       Mark       Philips             Edmonton      AB    +1 (780) 434-4554
# 14   Jennifer      Peterson            Vancouver      BC    +1 (604) 688-2255
# 15      Frank        Harris        Mountain View      CA    +1 (650) 253-0000
# 16       Jack         Smith              Redmond      WA    +1 (425) 882-8080
# 17   Michelle        Brooks             New York      NY    +1 (212) 221-3546
# 18        Tim         Goyer            Cupertino      CA    +1 (408) 996-1010
# 19        Dan        Miller        Mountain View      CA    +1 (650) 644-3358
# 20      Kathy         Chase                 Reno      NV    +1 (775) 223-7665
# 21    Heather       Leacock              Orlando      FL    +1 (407) 999-7788
# 22       John        Gordon               Boston      MA    +1 (617) 522-1333
# 23      Frank       Ralston              Chicago      IL    +1 (312) 332-3232
# 24     Victor       Stevens              Madison      WI    +1 (608) 257-0597
# 25    Richard    Cunningham           Fort Worth      TX    +1 (817) 924-7272
# 26    Patrick          Gray               Tucson      AZ    +1 (520) 622-4200
# 27      Julia       Barnett       Salt Lake City      UT    +1 (801) 531-7272
# 28     Robert         Brown              Toronto      ON    +1 (416) 363-8888
# 29     Edward       Francis               Ottawa      ON    +1 (613) 234-3322
# 30     Martha          Silk              Halifax      NS    +1 (902) 450-0450
# 31      Aaron      Mitchell             Winnipeg      MB    +1 (204) 452-6452
# 32      Ellie      Sullivan          Yellowknife      NT    +1 (867) 920-2233
# 33       João     Fernandes               Lisbon    None   +351 (213) 466-111
# 34   Madalena       Sampaio                Porto    None   +351 (225) 022-448
# 35     Hannah     Schneider               Berlin    None     +49 030 26550280
# 36       Fynn    Zimmermann            Frankfurt    None     +49 069 40598889
# 37     Niklas      Schröder               Berlin    None      +49 030 2141444
# 38    Camille       Bernard                Paris    None   +33 01 49 70 65 65
# 39  Dominique      Lefebvre                Paris    None   +33 01 47 42 71 71
# 40       Marc        Dubois                 Lyon    None   +33 04 78 30 30 30
# 41      Wyatt        Girard             Bordeaux    None   +33 05 56 96 96 96
# 42   Isabelle       Mercier                Dijon    None   +33 03 80 73 66 99
# 43      Terhi    Hämäläinen             Helsinki    None     +358 09 870 2000
# 44   Ladislav        Kovács             Budapest    None                 None
# 45       Hugh      O'Reilly               Dublin  Dublin      +353 01 6792424
# 46      Lucas       Mancini                 Rome      RM      +39 06 39733434
# 47   Johannes  Van der Berg            Amsterdam      VV      +31 020 6223130
# 48  Stanisław        Wójcik               Warsaw    None     +48 22 828 37 39
# 49    Enrique         Muñoz               Madrid    None      +34 914 454 454
# 50     Joakim     Johansson            Stockholm    None     +46 08-651 52 52
# 51       Emma         Jones               London    None    +44 020 7707 0707
# 52       Phil        Hughes               London    None    +44 020 7976 5722
# 53      Steve        Murray           Edinburgh     None    +44 0131 315 3300
# 54       Mark        Taylor               Sidney     NSW   +61 (02) 9332 3633
# 55      Diego     Gutiérrez         Buenos Aires    None  +54 (0)11 4311 4333
# 56       Luis         Rojas             Santiago    None    +56 (0)2 635 4444
# 57      Manoj        Pareek                Delhi    None    +91 0124 39883988
# 58       Puja    Srivastava            Bangalore    None     +91 080 22289999
#
#                             Email
# 0            luisg@embraer.com.br
# 1           leonekohler@surfeu.de
# 2             ftremblay@gmail.com
# 3           bjorn.hansen@yahoo.no
# 4        frantisekw@jetbrains.com
# 5                 hholy@gmail.com
# 6          astrid.gruber@apple.at
# 7           daan_peeters@apple.be
# 8           kara.nielsen@jubii.dk
# 9        eduardo@woodstock.com.br
# 10               alero@uol.com.br
# 11  roberto.almeida@riotur.gov.br
# 12       fernadaramos4@uol.com.br
# 13             mphilips12@shaw.ca
# 14            jenniferp@rogers.ca
# 15             fharris@google.com
# 16        jacksmith@microsoft.com
# 17              michelleb@aol.com
# 18               tgoyer@apple.com
# 19            dmiller@comcast.com
# 20            kachase@hotmail.com
# 21             hleacock@gmail.com
# 22         johngordon22@yahoo.com
# 23             fralston@gmail.com
# 24             vstevens@yahoo.com
# 25       ricunningham@hotmail.com
# 26           patrick.gray@aol.com
# 27            jubarnett@gmail.com
# 28               robbrown@shaw.ca
# 29            edfrancis@yachoo.ca
# 30           marthasilk@gmail.com
# 31         aaronmitchell@yahoo.ca
# 32         ellie.sullivan@shaw.ca
# 33            jfernandes@yahoo.pt
# 34              masampaio@sapo.pt
# 35      hannah.schneider@yahoo.de
# 36           fzimmermann@yahoo.de
# 37            nschroder@surfeu.de
# 38       camille.bernard@yahoo.fr
# 39    dominiquelefebvre@gmail.com
# 40        marc.dubois@hotmail.com
# 41          wyatt.girard@yahoo.fr
# 42      isabelle_mercier@apple.fr
# 43      terhi.hamalainen@apple.fi
# 44       ladislav_kovacs@apple.hu
# 45           hughoreilly@apple.ie
# 46         lucas.mancini@yahoo.it
# 47        johavanderberg@yahoo.nl
# 48         stanisław.wójcik@wp.pl
# 49         enrique_munoz@yahoo.es
# 50      joakim.johansson@yahoo.se
# 51         emma_jones@hotmail.com
# 52          phil.hughes@gmail.com
# 53          steve.murray@yahoo.uk
# 54           mark.taylor@yahoo.au
# 55       diego.gutierrez@yahoo.ar
# 56             luisrojas@yahoo.cl
# 57        manoj.pareek@rediff.com
# 58       puja_srivastava@yahoo.in
